# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data.describe()
# Out:
#              ABR        MAY        JUN        JUL        AGO        SEP  \
# count  62.000000  62.000000  62.000000  62.000000  62.000000  62.000000
# mean   15.809677  13.474194  14.891935  15.517742  16.827419  20.298387
# std     8.373489   8.366325  10.370028   9.789498  10.557263  10.908103
# min     0.400000   0.400000   0.600000   0.500000   0.500000   0.500000
# 25%    11.475000   9.450000   9.000000   9.350000  10.025000  12.425000
# 50%    14.150000  11.650000  11.150000  12.950000  14.500000  18.250000
# 75%    17.300000  15.075000  16.175000  18.600000  21.625000  24.825000
# max    56.000000  56.000000  56.000000  56.000000  56.000000  56.000000
#
#              OCT         NOV         DIC         ENE         FEB        MAR
# count  62.000000   62.000000   62.000000   62.000000   62.000000  62.000000
# mean   31.929032   58.579032   76.340323   61.816129   39.938710  24.570968
# std    15.623704   30.347869   48.030740   42.889344   23.884863  12.001317
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
datos = data.to_numpy()

# %%
type(datos)
# Out:
# numpy.ndarray

# %%
datos.shape
# Out:
# (62, 13)

# %%
data.columns
# Out:
# Index(['AÑO', 'ABR', 'MAY', 'JUN', 'JUL', 'AGO', 'SEP', 'OCT', 'NOV', 'DIC',
#        'ENE', 'FEB', 'MAR'],
#       dtype='object')

# %%
plt.plot(datos[:, 1:5], color = "r", linestyle = "--", linewidth=4, alpha = 0.5)

# %%
fig, ax = plt.subplots()

ax.plot(datos[:, 1], label = "Abril")
ax.plot(datos[:, 4], color = "g", linewidth = 5, label = "Julio")

ax.legend()
ax.set_xlabel("Fecha")
ax.set_ylabel("Precipitaciones")
ax.set_title("Precipitaciones")
# Out:
# Text(0.5, 1.0, 'Precipitaciones')

# %%
fig, ax = plt.subplots(nrows=3,ncols = 1)
ax[0].plot(datos[:, 1])
ax[1].plot(datos[:, 4])

# %%
import numpy as np

fig, ax = plt.subplots()

ax.scatter(x = np.arange(datos[:,].shape[0]), 
           y =datos[:,1],
          )

# %%
fig, ax = plt.subpl
